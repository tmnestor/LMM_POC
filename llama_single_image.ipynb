# %% [markdown]
# # Imports

# %%
from pathlib import Path
import random

import numpy as np
import torch
from PIL import Image
from transformers import AutoProcessor, MllamaForConditionalGeneration

# %% [markdown]
# # Set Random Seed for Reproducibility

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)
print("✅ Random seed set to 42 for reproducibility")
# Out:
# ✅ Random seed set to 42 for reproducibility

# %% [markdown]
# # Load the model

# %%
# Update this path to your local Llama model
# model_id = "/home/jovyan/shared_PTM/Llama-3.2-11B-Vision-Instruct"
model_id = "/home/jovyan/nfs_share/models/Llama-3.2-11B-Vision-Instruct"

print("🔧 Loading Llama-3.2-Vision model...")
model = MllamaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)
processor = AutoProcessor.from_pretrained(model_id)

# processor
# Out:
# 🔧 Loading Llama-3.2-Vision model...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# # Load the image

# %%
# Update this path to your test image
# imageName = "/home/jovyan/shared_PoC_data/evaluation_data/image_009.png"
imageName = "/home/jovyan/nfs_share/tod/LMM_POC/evaluation_data/image_008.png"
print("📁 Loading image...")
image = Image.open(imageName)
print(f"✅ Image loaded: {image.size}")
# Out:
# 📁 Loading image...
# ✅ Image loaded: (900, 1320)

# %% [markdown]
# # Define the prompt

# %%
# Visual Question Answering - ask a simple question about the image
prompt = """
You are an expert document analyser specializing in Date Grouped Australian Bank Statement extraction.
Date Grouped Bank Statements are date ordered, with one or more transactions for each date header.
Every transaction for a given date heading has a description, a debit/credit amount and finally a balance amount with a ' CR' suffix.
Extract all balance amounts along with their ' CR' suffix, the transaction dates (from the date heading) and transaction descriptions,
maintaining the same date ordering as the image, with every transaction appearing on its own row and remembering that some date headings have more than one balance.
"""

# Create message structure for Llama
messageDataStructure = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {
                "type": "text",
                "text": prompt,
            },
        ],
    }
]

print(f"💬 Prompt: {prompt}")
print("🤖 Generating response with Llama-3.2-Vision...")
# Out:
# 💬 Prompt:
# You are an expert document analyser specializing in Date Grouped Australian Bank Statement extraction.
# Date Grouped Bank Statements are date ordered, with one or more transactions for each date header.
# Every transaction for a given date heading has a description, a debit/credit amount and finally a balance amount with a ' CR' suffix.
# Extract all balance amounts along with their ' CR' suffix, the transaction dates (from the date heading) and transaction descriptions,
# maintaining the same date ordering as the image, with every transaction appearing on its own row and remembering that some date headings have more than one balance.
#
# 🤖 Generating response with Llama-3.2-Vision...

# %% [markdown]
# # Clean Response Function

# %%
def clean_llama_response(response: str) -> str:
    """Remove chat template artifacts and extract only the assistant's response."""
    start_marker = "<|start_header_id|>assistant<|end_header_id|>"
    end_marker = "<|eot_id|>"
    
    start_idx = response.find(start_marker)
    if start_idx != -1:
        start_idx += len(start_marker)
        end_idx = response.find(end_marker, start_idx)
        if end_idx != -1:
            return response[start_idx:end_idx].strip()
    
    return response.strip()

# %% [markdown]
# # Process the prompt

# %%
# Process the input
textInput = processor.apply_chat_template(
    messageDataStructure, add_generation_prompt=True
)
inputs = processor(image, textInput, return_tensors="pt").to(model.device)

# Generate response with deterministic parameters
output = model.generate(
    **inputs,
    max_new_tokens=2000,
    do_sample=False,
    temperature=None,
    top_p=None,
)
generatedOutput = processor.decode(output[0])

# Clean the response to remove chat artifacts
cleanedOutput = clean_llama_response(generatedOutput)

print("✅ Response generated successfully!")
print("\n" + "=" * 60)
print("CLEANED EXTRACTION:")
print("=" * 60)
print(cleanedOutput)
print("=" * 60)

# Save the cleaned response to a file
output_path = Path("llama_grouped_bank_statement_output.txt")

with output_path.open("w", encoding="utf-8") as text_file:
    text_file.write(cleanedOutput)

print(f"✅ Response saved to: {output_path}")
print(f"📊 File size: {output_path.stat().st_size} bytes")
# Out:
# ✅ Response generated successfully!
#
# ============================================================
# CLEANED EXTRACTION:
# ============================================================
# <|begin_of_text|><|begin_of_text|><|start_header_id|>user<|end_header_id|>
#
# <|image|>
# You are an expert document analyser specializing in Date Grouped Australian Bank Statement extraction.
# Date Grouped Bank Statements are date ordered, with one or more transactions for each date header.
# Every transaction for a given date heading has a description, a debit/credit amount and finally a balance amount with a'CR' suffix.
# Extract all balance amounts along with their'CR' suffix, the transaction dates (from the date heading) and transaction descriptions,
# maintaining the same date ordering as the image, with every transaction appearing on its own row and remembering that some date headings have more than one balance.
# <|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Here is the list of extracted balance amounts, transaction dates, and descriptions:
#
# **08/09/2025**
#
# * $48890.58 - EFTPOS Cash Out PRICELINE PHARMACY MACKAY QLD
# * $49212.76 - EFTPOS Purchase OFFICEWORKS BUSINESS ROCKHAMPTO...
# * $49277.09 - Mortgage Repayment MORT 0103P16754533 NAB
# * $49266.81 - OSKO Payment to MIKE CHEN 809845773133
# * $61312.57 - Direct Debit 15395P41608263 MWF 42730
# * $61511.48 - Salary Payment ATO 28782P60782100
# * $43405.77 - DD INSURANCE ACME CORP PTY LTD 82321942151853
# * $43440.81 - Auto Payment UTILITIES AGL 7240P85943944
# * $43708.81 - DIRECT CREDIT SALARY 6080P677812986
# * $39296.85 - BPAY Payment BILLER60279 CRN 9813018480
# * $41754.72 - Professional Services Red Energy 98073P31959417
# * $42025.03 - Card Purchase RED ROOSTER Paramatta SA
# * $43882.12 - Credit Card Payment CC 72599P33283283298
# * $44203.72 - EFTPOS Cash Out PRICELINE PHARMACY BRISBANE QLD
# * $44226.28 - Card Purchase CHEMIST WAREHOUSE DISCOUNT Richmo...
# * $38747.07 - Fortnightly Pay ATO PAYROLL 91032P35687918
# * $34291.61 - PAY RUN ACME CORP PTY LTD 99584P07785218
# * $26339.68 - Salary Payment ATO 30175P32361419
# * $20423.46 - Online Purchase amazon.com.au AUS
# * $20409.76 - Salary Payment ATO 28773P16041610
# * $22754.86 - Transfer To Vicks Account NetBank 54381P90841102
# * $19213.59 - Salary Payment ATO 94514P80490207
# * $19940.07 - Transfer To Western Port Marina NetBank From Tod
# * $20141.21 - Subscription Netflix 33588P77385123
# * $20352.49 - Contactless Payment Cinema CAIRNS QLD
# * $20385.73 - Auto Payment UTILITIES Red Energy 15107P21771655
# * $20531.43 - Contactless Payment Restaurant MACKAY QLD
# * $13330.24 - Fortnightly Pay ATO PAYROLL 36358P70254998
# * $11088.85 - Centrelink Payment JobSeeker 59392P56090878
# * $11115.91 - International Transaction Fee
# * $11594.77 - Equipment Purchase OfficeMax Australia 13554P45...
# * $11855.48 - International ATM USA USD
# * $5460.39 - Dividend Payment PREMIUM CORP PTY LTD 7353SP419...
# * $5899.73 - Invoice Payment HARVEY NORMAN FLAGSHIP PTY LTD...
# * $5940.78 - Online Purchase ebay.com.au AUS
# * $6133.98 - Subscription Spotify Monthly 15369P58427775
# * $6157.78 - International Transaction Fee
# * $6792.06 - Business Expense IT Equipment 66969P86141679
# * $6792.06 - Auto Payment UTILITIES Energy Australia 47683P7...
# * $6884.90 - Auto Payment UTILITIES Red Energy 81338P61572286
#
# **07/09/2025**
#
# * $322.18 - EFTPOS Cash Out PRICELINE PHARMACY MACKAY QLD
# * $64.33 - EFTPOS Purchase OFFICEWORKS BUSINESS ROCKHAMPTO...
# * $649.79 - Mortgage Repayment MORT 0103P16754533 NAB
# * $1365.43 - OSKO Payment to MIKE CHEN 809845773133
# * $199.17 - Direct Debit 15395P41608263 MWF 42730
# * $45.04 - Salary Payment ATO 28782P60782100
# * $257.50 - DD INSURANCE ACME CORP PTY LTD 82321942151853
# * $257.50 - Auto Payment UTILITIES AGL 7240P85943944
# * $37.68 - DIRECT CREDIT SALARY 6080P677812986
# * $37.68 - BPAY Payment BILLER60279 CRN 9813018480
# * $270.31 - Professional Services Red Energy 98073P31959417
# * $1957.09 - Card Purchase RED ROOSTER Paramatta SA
# * $221.60 - Credit Card Payment CC 72599P33283283298
# * $222.56 - EFTPOS Cash Out PRICELINE PHARMACY BRISBANE QLD
# * $222.56 - Card Purchase CHEMIST WAREHOUSE DISCOUNT Richmo...
# * $4455.46 - Fortnightly Pay ATO PAYROLL 91032P35687918
# * $7951.93 - PAY RUN ACME CORP PTY LTD 99584P07785218
# * $6013.70 - Salary Payment ATO 30175P32361419
# * $2345.10 - Online Purchase amazon.com.au AUS
# * $2345.10 - Salary Payment ATO 28773P16041610
# * $728.48 - Transfer To Vicks Account NetBank 54381P90841102
# * $201.14 - Salary Payment ATO 94514P80490207
# * $201.14 - Transfer To Western Port Marina NetBank From Tod
# * $211.28 - Subscription Netflix 33588P77385123
# * $33.24 - Contactless Payment Cinema CAIRNS QLD
# * $145.70 - Auto Payment UTILITIES Red Energy 15107P21771655
# * $27.06 - Contactless Payment Restaurant MACKAY QLD
# * $478.86 - Fortnightly Pay ATO PAYROLL 36358P70254998
# * $260.71 - Centrelink Payment JobSeeker 59392P56090878
# * $229.39 - International Transaction Fee
# * $229.39 - Equipment Purchase OfficeMax Australia 13554P45...
# * $257.95 - Dividend Payment PREMIUM CORP PTY LTD 7353SP419...
# * $166.22 - Invoice Payment HARVEY NORMAN FLAGSHIP PTY LTD...
# * $186.22 - Online Purchase ebay.com.au AUS
# * $33.83 - Subscription Spotify Monthly 15369P58427775
# * $63.83 - International Transaction Fee
# * $91.04 - Business Expense IT Equipment 66969P86141679
# * $91.04 - Auto Payment UTILITIES Energy Australia 47683P7...
# * $389.57 - Auto Payment UTILITIES Red Energy 81338P61572286
#
# **06/09/2025**
#
# * $64890.58 - EFTPOS Cash Out PRICELINE PHARMACY MACKAY QLD
# * $49212.76 - EFTPOS Purchase OFFICEWORKS BUSINESS ROCKHAMPTO...
# * $49277.09 - Mortgage Repayment MORT 0103P16754533 NAB
# * $49266.81 - OSKO Payment to MIKE CHEN 809845773133
# * $61312.57 - Direct Debit 15395P41608263 MWF 42730
# * $61511.48 - Salary Payment ATO 28782P60782100
# * $43405.77 - DD INSURANCE ACME CORP PTY LTD 82321942151853
# * $43440.81 - Auto Payment UTILITIES AGL 7240P85943944
# * $43708.81 - DIRECT CREDIT SALARY 6080P677812986
# * $39296.85 - BPAY Payment BILLER60279 CRN 9813018480
# * $39296.85 - Professional Services Red Energy 98073P31959417
# * $41754.72 - Card Purchase RED ROOSTER Paramatta SA
# * $42025.03 - Credit Card Payment CC 72599P33283283298
# * $43882.12 - EFTPOS Cash Out PRICELINE PHARMACY BRISBANE QLD
# * $44203.72 - Card Purchase CHEMIST WAREHOUSE DISCOUNT Richmo...
# * $44226.28 - Fortnightly Pay ATO PAYROLL 91032P35687918
# * $38747.07 - PAY RUN ACME CORP PTY LTD 99584P07785218
# * $34291.61 - Salary Payment ATO 30175P32361419
# * $26339.68 - Online Purchase amazon.com.au AUS
# * $20423.46 - Salary Payment ATO 28773P16041610
# * $20409.76 - Transfer To Vicks Account NetBank 54381P90841102
# * $22754
# ============================================================
# ✅ Response saved to: llama_grouped_bank_statement_output.txt
# 📊 File size: 6416 bytes
